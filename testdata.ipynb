# %%
# !git clone -b dev --single-branch https://github.com/swecomic/xray
# Out:
# Cloning into 'xray'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 310 (delta 20), reused 28 (delta 9), pack-reused 263
# Receiving objects: 100% (310/310), 7.71 MiB | 5.23 MiB/s, done.
# Resolving deltas: 100% (153/153), done.

# %%
import torch as torch
import random as random
import numpy as np
from PIL import Image, ImageDraw, ImageFont

import matplotlib
import matplotlib.pyplot as plt

# %%
# import

import os
import torch
import torchvision
import pandas as pd
from PIL import Image
from pycocotools.coco import COCO
from torch.utils import data

# Log Tag
Tag = 'XrayDataloader'

# coalb detect logic
try:
    import google.colab

    IN_COLAB = True
except:
    IN_COLAB = False

if IN_COLAB:
    from xray.Utils.logger import log
else:
    from Utils.logger import log

class XrayDataSet(data.Dataset):
    def __init__(self, root, annotation, class_name=None, img_type=None, flag=None, transforms=None) :
        self.root = root
        self.coco = COCO(annotation)
        self.class_name = class_name
        self.img_type = img_type
        self.flag = flag
        self.transforms = transforms

        if self.class_name is not None :
            class_id = sorted(self.coco.getCatIds(catNms=self.class_name))
            self.ids = self.make_id_list(class_id, self.class_name, self.img_type, self.flag)
        else :
            self.ids = self.isValid(list(sorted(self.coco.imgs.keys())), class_name=None, img_type=self.img_type, flag=self.flag)

        self.ids = list(set(self.ids))
        log(Tag, 'Dataset Created')

    def __getitem__(self, item) :
        # Own coco file
        coco = self.coco

        # Image ID
        img_id = self.ids[item]

        # List: get annotation id from coco
        ann_ids = coco.getAnnIds(imgIds=img_id)

        # Dictionary: target coco_annotation file for an image
        coco_annotation = coco.loadAnns(ann_ids)

        # Load Image
        img_info = coco.loadImgs(coco_annotation[0]["image_id"])

        # file path
        file_path = img_info[0]["path"].split('\\', maxsplit=8)[-1]
        #log(Tag, str(file_path))
        # open the input image
        image_path = os.path.join(self.root, file_path.replace('\\', '/'))
        img = Image.open(image_path)

        # number of objects in the image
        num_objs = len(coco_annotation)

        # Bounding boxes for objects
        # In coco format, bbox = [xmin, ymin, width, height]
        # In pytorch, the input should be [xmin, ymin, xmax, ymax]
        boxes = []
        class_id = []
        for i in range(num_objs):
            # bbox
            xmin = coco_annotation[i]['bbox'][0]
            ymin = coco_annotation[i]['bbox'][1]
            xmax = xmin + coco_annotation[i]['bbox'][2]
            ymax = ymin + coco_annotation[i]['bbox'][3]
            boxes.append([xmin, ymin, xmax, ymax])

            # class_id
            cid = coco_annotation[i]["category_id"]
            class_id.append(cid)

        # file_name = img_info[0]["file_name"]
        file_name = file_path
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        class_names = self.get_class_names(class_id)
        class_id = torch.as_tensor(class_id)
        image_id = coco_annotation[0]["image_id"]

        # Tensorise
        image_id = torch.tensor([image_id])

        # number of objects in the image
        num_objs = len(coco_annotation)

        # Annotation is in dictionary format
        xray_annotation = {"boxes" : boxes, "class_id": class_id, "image_id" : image_id, 'filename' : file_name,
                           'class_names' : class_names}

        if self.transforms is not None :
            img = self.transforms(img)

        return img, xray_annotation

    def make_id_list(self, class_id, class_name, img_type, flag) :
        # 공유폴더에 이미지가 존재하는것만 index를 만들어줌
        ids = []

        if isinstance(class_id, list):
            for id in class_id:
                find_id = self.coco.getImgIds(catIds=[id])
                ids.extend(self.isValid(find_id, class_name, img_type, flag))
        else:
            find_id = self.coco.getImgIds(catIds=class_id)
            ids.extend(self.isValid(find_id, class_name, img_type, flag))

        return ids

    def isValid(self, find_id, class_name, img_type, flag):
        ids = []
        invalid = []
        log(Tag, 'isValid check len : ' + str(len(find_id)))
        for i in find_id :
            if flag == "1":
                class_name_anno = self.coco.imgs[i]['path'].split('\\')[8]
                img_type_anno = self.coco.imgs[i]['path'].split('\\')[9]

                if class_name_anno in class_name and img_type_anno in self.get_img_type(img_type):
                    file = self.coco.imgs[i]['path'].split('\\', maxsplit=8)[-1].replace('\\', '/')                    
                    if os.path.isfile(os.path.join(self.root, file)):                      
                        ids.append(i)
                    else :
                        invalid.append(file)
            else:
                file = self.coco.imgs[i]['path'].split('\\', maxsplit=8)[-1].replace('\\', '/')
                if os.path.isfile(os.path.join(self.root, file)):
                    ids.append(i)
                else :
                    invalid.append(file)
        if invalid:
            log(Tag, 'Empty file found: '+str(len(invalid)))
            if os.path.exists('./debug') is not True :
                os.makedirs('debug')
            with open('./debug/empty_file.txt', 'w') as fp :
                for s in invalid :
                    fp.write(str(s) + "\n")
        return ids

    def get_img_type(self, img_type):

        img_type_dict = {"SD":"Single_Default"
                       ,"SO":"Single_Other"
                       ,"MC":"Multiple_Categories"
                       ,"MO":"Multiple_Other"
        }
        return [img_type_dict[x] for x in img_type]

    # show all category_id and its name
    def get_object_info(self):
        cat_ids = self.coco.getCatIds()
        cats = self.coco.loadCats(cat_ids)
        df_rows = []
        for cat in sorted(cats, key=lambda x: x["id"]):
            #image count in our path
            path_data = self.make_id_list(cat["id"], class_name=None, img_type=None, flag=None)
            path_data_cnt = len(path_data)
            #image count in annotation file
            anno_data = self.coco.getImgIds(catIds=cat["id"])
            anno_data_cnt = len(anno_data)
            sd, so, mc, mo = self.get_type_count(path_data)
            df_rows = df_rows + [[cat['id'], cat['name'], anno_data_cnt, path_data_cnt, sd, so, mc, mo]]

        return pd.DataFrame(df_rows, columns=['ID', "Name", 'ANNO_TOTAL', 'PATH_TOTAL', 'Single_Default', 'Single_Other',
                                              'Multiple_Categories', 'Multiple_Other'])

    def get_type_count(self, anno_data):
        single_Default = 0
        single_Other = 0
        multiple_Categories = 0
        multiple_Other = 0
        for anno in anno_data :
            imgs = self.coco.loadImgs(anno)
            if 'Single_Default' in imgs[0]['path'] :
                single_Default += 1
            elif 'Single_Other' in imgs[0]['path'] :
                single_Other += 1
            elif 'Multiple_Categories' in imgs[0]['path'] :
                multiple_Categories += 1
            else:
                multiple_Other += 1
        return single_Default, single_Other, multiple_Categories, multiple_Other

    def __len__(self):
        return len(self.ids)

    def class_id_to_str(self, class_id):
        class_dict = {34:'ZippoOil', 37:'Chisel', 24:'Scissors', 30:'SupplymentaryBattery', 22:'PrtableGas',
                      36:'Plier', 15:'Knife', 17:'Lighter', 11:'Hammer', 9:'Gun', 20:'MetalPipe', 25:'Screwdriver',
                      4:'Axe', 28:'Spanner', 23:'Saw', 10:'GunParts', 1:'Aerosol', 19:'Match', 2:'Alcohol',
                      39:'Electronic cigarettes(Liquid)', 12:'HandCuffs', 41:'Throwing Knife', 32:'Thinner',
                      40:'stun gun', 38:'Electronic cigarettes', 26:'SmartPhone', 13:'HDD', 27:'SolidFuel',
                      6:'Battery', 3:'Awl', 18:'Liquid', 33:'USB', 31:'TabletPC', 29:'SSD', 21:'NailClippers',
                      16:'Laptop', 7:'Bullet', 8:'Firecracker', 5:'Bat'}

        return class_dict[class_id]

    def get_class_names(self, class_ids):
        class_name = []
        for class_id in class_ids:
            class_name.append(self.class_id_to_str(class_id))
        return class_name

def get_transform() :
    custom_transforms = [torchvision.transforms.ToTensor()]
    return torchvision.transforms.Compose(custom_transforms)


def collate_fn(batch) :
    return tuple(zip(*batch))

class XrayDataLoader2() :
    def __init__(self, root, annotation, batch_size, class_name, img_type, flag, transfroms=None) :
        self.xray_data_set = XrayDataSet(root, annotation, class_name, img_type, flag, transfroms)
        self.batch_size = batch_size
        self.data_loader = torch.utils.data.DataLoader(
            dataset=self.xray_data_set,
            batch_size=self.batch_size,
            shuffle=True,
            num_workers=6,
            collate_fn=collate_fn,)

    def get_data_loader(self):
        return self.data_loader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-beeb0a559822> in <module>
#      23     from xray.Utils.logger import log
#      24 else:
# ---> 25     from Utils.logger import log
#      26
#      27 class XrayDataSet(data.Dataset):
#
# ModuleNotFoundError: No module named 'Utils'

# %%
######[GOLBAL VLAUE]#######
# Logger
Tag = 'Eval'

# parameters
train_batch_size = 32

# Training class selection
class_name = ['ZippoOil']

# SD = Single Default / SO = Single Others / MO = Multiple Others / MC = Multiple Categories
img_type = ["SD"]
# img_type = ["SD", "SO"]

# Image Extraction Filter
# 0: get images of classes from all folders
# 1: get images of classes corresponding to the folders of specified class names
flag = "1"

def check_dir(path):
    if path == 'colab':
        train_data_dir = '/content/drive/' + 'Shared drives' + '/YS_NW/2.Data/Test/Data/'        
        #train_coco = '/content/drive/Shared drives/YS_NW/2.Data/Test/Meta/CoCo/coco_eval_rapiscan.json'
        train_coco = '/content/drive/MyDrive/2020_인공지능전공_프로젝트/coco_eval_rapiscan_change.json'
    elif path == 'google_drive':
        train_data_dir = 'G:/공유 드라이브/YS_NW/2.Data/Train/Data/'
        train_coco = 'G:/공유 드라이브/YS_NW/2.Data/Train/Meta/CoCo/coco_rapiscan.json'
    else:
        train_data_dir = '/data/jiylee/dataset/xray/Train/Data/'
        train_coco = '/data/jiylee/dataset/xray/Train/Meta/CoCo/coco_rapiscan.json'

    return train_data_dir, train_coco


def get_data_loader():
    train_data_dir, train_data_coco = check_dir(LOCATION_PATH)
    _xraydataloader = XrayDataLoader2(root=train_data_dir, annotation=train_data_coco,
                                          class_name=class_name,
                                          img_type=img_type,
                                          flag=flag,
                                          batch_size=train_batch_size)
    _data_loader = _xraydataloader.get_data_loader()
    log(Tag, 'get_data_loader: loader make complete, total dataset : ' + str(len(_data_loader.dataset)))
    return _xraydataloader, _data_loader,

# show image
def check_dataset(data_set, num_of_item):
    sample = random.sample(range(0, len(data_set) - 1), num_of_item)
    for i in sample:        
        plt.figure(figsize=(10,8))
        sample_img = data_set[i][0]
        sample_anno = data_set[i][1]
        bb = np.array(sample_anno["boxes"], dtype=np.float32)
        filename = np.array(sample_anno["filename"])
        print(sample_img)
        class_names = np.array(sample_anno["class_names"])
        original = plt.subplot(2,1,2)
        for i in range(len(bb)):
            crop_img = sample_img.crop(bb[i])
            box_fig = plt.subplot(2, len(bb), i+1)
            box_img = np.array(crop_img)
            box_fig.imshow(box_img)
            box_fig.set_title(class_names[i])
            box_fig.axis('off')
        for i in range(len(bb)):
            draw = ImageDraw.Draw(sample_img)
            draw.rectangle(bb[i], outline='red', width =3)
        np_sample = np.array(sample_img)
        original.imshow(np_sample)
        plt.suptitle(filename)
        plt.tight_layout()
        plt.show()
        print(filename)
    return sample

if __name__ == '__main__':
    # location
    LOCATION_PATH = 'colab'
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
    xray_loader, data_loader = get_data_loader()
    sample = check_dataset(data_loader.dataset, 10)

# torch.cuda.get_device_name()
# torch.cuda.is_available()
# torch.__version__
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import json

# %%
with open('/content/drive/MyDrive/2020_인공지능전공_프로젝트/coco_eval_rapiscan_change.json') as json_file:
    itemData = json.load(json_file)

# %%
itemData
# Out:
# {'annotations': [{'area': 0,
#    'bbox': [731.0, 409.0, 115.0, 125.0],
#    'category_id': 34,
#    'color': '',
#    'id': 1,
#    'image_id': 1,
#    'iscrowd': False,
#    'segmentation': [[818.7,
#      532.9,
#      833.1,
#      513.1,
#      846.3,
#      488.29999999999995,
#      759.3,
#      409.1,
#      749.6,
#      424.70000000000005,
#      742.3,
#      425.79999999999995,
#      738.0,
#      433.20000000000005,
#      738.0,
#      444.5,
#      731.0,
#      458.0,
#      817.2,
#      534.1]]},
#   {'area': 0,
#    'bbox': [644.0, 284.0, 78.0, 151.0],
#    'category_id': 34,
#    'color': '',
#    'id': 2,
#    'image_id': 1,
#    'iscrowd': False,
#    'segmentation': [[680.2,
#      434.1,
#      682.0,
#      435.0,
#      702.1,
#      431.29999999999995,
#      722.1,
#      415.5,
#      691.3,
#      303.20000000000005,
#      677.4,
#      303.20000000000005,
#      670.4,
#      284.1,
#      650.8,
#      287.9,
#      656.9,
#      313.0,
#      643.8,
#      319.5,
#      677.4,
#      432.20000000000005]]},
#   {'area': 0,
#    'bbox': [569.0, 449.0, 133.0, 85.0],
#    'category_id': 30,
#    'color': '',
#    'id': 3,
#    'image_id': 1,
#    'iscrowd': False,
#    'segmentation': [[571.4,
#      521.0,
#      695.3,
#      534.6,
#      702.4,
#      457.29999999999995,
#      576.3,
#      448.6,
#      570.8,
#      452.79999999999995,
#      568.5,
#      518.8]]},
#   {'area': 0,
#    'bbox': [736.0, 486.0, 67.0, 67.0],
#    'category_id': 17,
#    'color': '',
#    'id': 4,
#    'image_id': 1,
#    'iscrowd': False,
#    'segmentation': [[789.8,
#      551.5,
#      802.8,
#      525.3,
#      800.8,
#      515.6,
#      754.6,
#      487.79999999999995,
#      747.5,
#      485.9,
#      735.8,
#      511.1,
#      736.1,
#      521.4,
#      786.3,
#      552.5]]},
#   {'area': 0,
#    'bbox': [839.0, 385.0, 41.0, 170.0],
#    'category_id': 15,
#    'color': '',
#    'id': 5,
#    'image_id': 1,
#    'iscrowd': False,
#    'segmentation': [[848.0,
#      554.2,
#      860.6,
#      540.3,
#      861.7,
#      517.6,
#      870.1,
#      470.4,
#      879.7,
#      459.79999999999995,
#      870.9,
#      449.5,
#      878.4,
#      412.20000000000005,
#      875.2,
#      394.6,
#      871.1,
#      384.0,
#      859.4,
#      415.0,
#      839.3,
#      519.2,
#      846.1,
#      555.4]]},
#   {'area': 0,
#    'bbox': [691.0, 539.0, 109.0, 112.0],
#    'category_id': 34,
#    'color': '',
#    'id': 6,
#    'image_id': 2,
#    'iscrowd': False,
#    'segmentation': [[796.9,
#      648.4,
#      800.4,
#      635.1,
#      791.4,
#      628.6,
#      794.6,
#      610.2,
#      715.7,
#      539.1,
#      700.5,
#      557.2,
#      690.8,
#      583.7,
#      765.8,
#      651.6,
#      782.0,
#      643.8,
#      795.9,
#      650.0]]},
#   {'area': 0,
#    'bbox': [750.0, 519.0, 105.0, 127.0],
#    'category_id': 34,
#    'color': '',
#    'id': 7,
#    'image_id': 2,
#    'iscrowd': False,
#    'segmentation': [[823.9,
#      645.5,
#      834.6,
#      640.0,
#      852.4,
#      625.5,
#      855.3,
#      610.9,
#      785.1,
#      519.1,
#      755.7,
#      546.6,
#      750.2,
#      558.8,
#      822.0,
#      646.8]]},
#   {'area': 0,
#    'bbox': [660.0, 353.0, 108.0, 171.0],
#    'category_id': 30,
#    'color': '',
#    'id': 8,
#    'image_id': 2,
#    'iscrowd': False,
#    'segmentation': [[661.9,
#      495.79999999999995,
#      716.6,
#      523.7,
#      767.9,
#      380.5,
#      710.4,
#      352.6,
#      660.4,
#      492.29999999999995]]},
#   {'area': 0,
#    'bbox': [790.0, 481.0, 135.0, 59.0],
#    'category_id': 15,
#    'color': '',
#    'id': 9,
#    'image_id': 2,
#    'iscrowd': False,
#    'segmentation': [[825.1,
#      537.9,
#      868.7,
#      519.3,
#      875.5,
#      520.7,
#      884.9,
#      510.4,
#      898.1,
#      505.6,
#      925.1,
#      487.79999999999995,
#      920.5,
#      484.79999999999995,
#      904.3,
#      481.1,
#      868.7,
#      494.5,
#      863.3,
#      486.20000000000005,
#      861.3,
#      487.20000000000005,
#      856.0,
#      496.70000000000005,
#      821.2,
#      510.6,
#      814.1,
#      516.9,
#      797.8,
#      514.5,
#      789.6,
#      535.8,
#      800.6,
#      540.1,
#      823.4,
#      537.5]]},
#   {'area': 0,
#    'bbox': [785.0, 445.0, 68.0, 59.0],
#    'category_id': 17,
#    'color': '',
#    'id': 10,
#    'image_id': 2,
#    'iscrowd': False,
#    'segmentation': [[837.4,
#      502.5,
#      844.7,
#      504.4,
#      853.2,
#      467.1,
#      799.3,
#      445.4,
#      792.7,
#      445.0,
#      784.5,
#      481.5,
#      787.5,
#      486.20000000000005,
#      835.0,
#      501.70000000000005]]},
#   {'area': 0,
#    'bbox': [823.0, 520.0, 105.0, 126.0],
#    'category_id': 34,
#    'color': '',
#    'id': 11,
#    'image_id': 3,
#    'iscrowd': False,
#    'segmentation': [[857.5,
#      645.8,
#      927.7,
#      562.7,
#      928.0,
#      552.3,
#      919.6,
#      539.7,
#      893.7,
#      520.0,
#      890.2,
#      526.5,
#      825.8,
#      606.0,
#      822.6,
#      615.7,
#      835.5,
#      632.5,
#      858.2,
#      646.8]]},
#   {'area': 0,
#    'bbox': [888.0, 540.0, 99.0, 112.0],
#    'category_id': 34,
#    'color': '',
#    'id': 12,
#    'image_id': 3,
#    'iscrowd': False,
#    'segmentation': [[913.7,
#      651.4,
#      987.0,
#      585.9,
#      983.0,
#      562.7,
#      964.7,
#      539.6,
#      887.9,
#      613.1,
#      891.9,
#      632.0,
#      910.5,
#      651.7]]},
#   {'area': 0,
#    'bbox': [911.0, 351.0, 106.0, 173.0],
#    'category_id': 30,
#    'color': '',
#    'id': 13,
#    'image_id': 3,
#    'iscrowd': False,
#    'segmentation': [[966.5,
#      523.7,
#      1015.0,
#      499.29999999999995,
#      1017.4,
#      488.4,
#      968.8,
#      350.70000000000005,
#      910.6,
#      383.6,
#      962.2,
#      523.3]]},
#   {'area': 0,
#    'bbox': [755.0, 482.0, 137.0, 60.0],
#    'category_id': 15,
#    'color': '',
#    'id': 14,
#    'image_id': 3,
#    'iscrowd': False,
#    'segmentation': [[808.7,
#      518.8,
#      846.4,
#      535.0,
#      871.4,
#      541.5,
#      892.0,
#      536.8,
#      887.8,
#      525.6,
#      880.1,
#      515.7,
#      825.3,
#      498.6,
#      816.1,
#      484.9,
#      810.5,
#      495.0,
#      782.0,
#      482.0,
#      762.5,
#      482.0,
#      754.4,
#      487.4,
#      804.0,
#      518.8]]},
#   {'area': 0,
#    'bbox': [827.0, 446.0, 68.0, 60.0],
#    'category_id': 17,
#    'color': '',
#    'id': 15,
#    'image_id': 3,
#    'iscrowd': False,
#    'segmentation': [[837.4,
#      505.7,
#      895.0,
#      484.9,
#      895.3,
#      470.70000000000005,
#      885.9,
#      446.1,
#      826.3,
#      468.20000000000005,
#      835.5,
#      504.6]]},
#   {'area': 0,
#    'bbox': [826.0, 351.0, 77.0, 143.0],
#    'category_id': 34,
#    'color': '',
#    'id': 16,
#    'image_id': 4,
#    'iscrowd': False,
#    'segmentation': [[862.6,
#      494.6,
#      903.4,
#      479.5,
#      903.4,
#      470.20000000000005,
#      871.9,
#      351.1,
#      856.8,
#      355.29999999999995,
#      855.2,
#      352.20000000000005,
#      842.0,
#      354.5,
#      841.3,
#      361.9,
#      825.7,
#      369.70000000000005,
#      860.7,
#      493.5]]},
#   {'area': 0,
#    'bbox': [897.0, 384.0, 82.0, 144.0],
#    'category_id': 34,
#    'color': '',
#    'id': 17,
#    'image_id': 4,
#    'iscrowd': False,
#    'segmentation': [[944.2,
#      527.8,
#      968.2,
#      522.7,
#      979.4,
#      501.6,
#      939.1,
#      399.20000000000005,
#      921.2,
#      399.6,
#      915.4,
#      384.0,
#      896.8,
#      394.5,
#      901.8,
#      413.1,
#      897.5,
#      424.4,
#      940.2,
#      526.8]]},
#   {'area': 0,
#    'bbox': [954.0, 437.0, 123.0, 160.0],
#    'category_id': 30,
#    'color': '',
#    'id': 18,
#    'image_id': 4,
#    'iscrowd': False,
#    'segmentation': [[954.6,
#      559.1,
#      1003.1,
#      597.5,
#      1074.5,
#      487.29999999999995,
#      1077.2,
#      474.1,
#      1038.0,
#      438.0,
#      1027.5,
#      436.79999999999995,
#      953.4,
#      556.0]]},
#   {'area': 0,
#    'bbox': [855.0, 621.0, 68.0, 60.0],
#    'category_id': 17,
#    'color': '',
#    'id': 19,
#    'image_id': 4,
#    'iscrowd': False,
#    'segmentation': [[914.2,
#      677.9,
#      923.3,
#      663.7,
#      923.3,
#      651.0,
#      872.1,
#      620.5,
#      857.5,
#      645.3,
#      855.1,
#      652.9,
#      907.2,
#      681.1]]},
#   {'area': 0,
#    'bbox': [822.0, 569.0, 141.0, 41.0],
#    'category_id': 15,
#    'color': '',
#    'id': 20,
#    'image_id': 4,
#    'iscrowd': False,
#    'segmentation': [[824.6,
#      596.8,
#      837.8,
#      602.9,
#      877.6,
#      600.0,
#      882.1,
#      610.7,
#      890.2,
#      601.0,
#      898.3,
#      597.7,
#      904.1,
#      600.0,
#      926.1,
#      596.8,
#      939.0,
#      591.9,
#      951.3,
#      599.0,
#      963.3,
#      581.9,
#      962.7,
#      578.0,
#      938.7,
#      569.0,
#      893.5,
#      574.5,
#      874.7,
#      574.8,
#      868.2,
#      579.3,
#      821.3,
#      593.5]]},
#   {'area': 0,
#    'bbox': [702.0, 384.0, 83.0, 146.0],
#    'category_id': 34,
#    'color': '',
#    'id': 21,
#    'image_id': 5,
#    'iscrowd': False,
#    'segmentation': [[737.5,
#      529.6,
#      784.9,
#      426.70000000000005,
#      778.3,
#      412.4,
#      784.9,
#      393.70000000000005,
#      766.6,
#      384.0,
#      755.4,
#      401.1,
#      743.0,
#      397.6,
#      702.2,
#      495.79999999999995,
#      703.4,
#      509.8,
#      732.9,
#      530.3]]},
#   {'area': 0,
#    'bbox': [776.0, 351.0, 77.0, 144.0],
#    'category_id': 34,
#    'color': '',
#    'id': 22,
#    'image_id': 5,
#    'iscrowd': False,
#    'segmentation': [[819.8,
#      495.0,
#      853.2,
#      368.5,
#      838.8,
#      355.29999999999995,
#      809.3,
#      351.1,
#      776.0,
#      478.70000000000005,
#      817.5,
#      495.0]]},
#   {'area': 0,
#    'bbox': [603.0, 433.0, 126.0, 166.0],
#    'category_id': 30,
#    'color': '',
#    'id': 23,
#    'image_id': 5,
#    'iscrowd': False,
#    'segmentation': [[678.9,
#      597.7,
#      729.2,
#      560.4,
#      649.6,
#      433.29999999999995,
#      603.0,
#      476.1,
#      676.1,
#      599.5]]},
#   {'area': 0,
#    'bbox': [714.0, 571.0, 143.0, 40.0],
#    'category_id': 15,
#    'color': '',
#    'id': 24,
#    'image_id': 5,
#    'iscrowd': False,
#    'segmentation': [[798.2,
#      609.8,
#      802.1,
#      599.1,
#      839.6,
#      604.6,
#      857.7,
#      593.9,
#      807.9,
#      576.5,
#      729.0,
#      570.7,
#      714.2,
#      582.6,
#      727.1,
#      595.9,
#      770.4,
#      598.5,
#      796.0,
#      610.8]]},
#   {'area': 0,
#    'bbox': [755.0, 623.0, 68.0, 59.0],
#    'category_id': 17,
#    'color': '',
#    'id': 25,
#    'image_id': 5,
#    'iscrowd': False,
#    'segmentation': [[771.1,
#      682.1,
#      823.4,
#      654.9,
#      823.4,
#      648.4,
#      809.4,
#      623.1,
#      755.2,
#      652.7,
#      755.5,
#      657.9,
#      767.9,
#      682.1]]},
#   {'area': 0,
#    'bbox': [725.0, 344.0, 158.0, 125.0],
#    'category_id': 34,
#    'color': '',
#    'id': 26,
#    'image_id': 6,
#    'iscrowd': False,
#    'segmentation': [[867.6,
#      467.29999999999995,
#      874.4,
#      434.9,
#      877.1,
#      435.20000000000005,
#      881.4,
#      416.9,
#      876.8,
#      416.1,
#      883.1,
#      382.20000000000005,
#      742.0,
#      344.0,
#      724.8,
#      430.6,
#      866.8,
#      468.79999999999995]]},
#   {'area': 0,
#    'bbox': [885.0, 475.0, 110.0, 109.0],
#    'category_id': 34,
#    'color': '',
#    'id': 27,
#    'image_id': 6,
#    'iscrowd': False,
#    'segmentation': [[898.3,
#      578.1,
#      906.9,
#      573.0,
#      917.7,
#      584.0,
#      990.5,
#      522.6,
#      995.1,
#      518.0,
#      989.4,
#      491.1,
#      968.1,
#      474.6,
#      894.0,
#      538.5,
#      895.3,
#      553.0,
#      884.3,
#      561.9,
#      894.5,
#      580.0]]},
#   {'area': 0,
#    'bbox': [685.0, 476.0, 111.0, 108.0],
#    'category_id': 34,
#    'color': '',
#    'id': 28,
#    'image_id': 7,
#    'iscrowd': False,
#    'segmentation': [[765.8,
#      582.6,
#      773.2,
#      574.0,
#      785.2,
#      581.0,
#      795.7,
#      560.1,
#      785.2,
#      552.7,
#      788.3,
#      538.7,
#      712.6,
#      475.9,
#      708.0,
#      475.9,
#      689.4,
#      498.4,
#      684.7,
#      517.0,
#      761.9,
#      584.1]]},
#   {'area': 0,
#    'bbox': [797.0, 344.0, 157.0, 124.0],
#    'category_id': 34,
#    'color': '',
#    'id': 29,
#    'image_id': 7,
#    'iscrowd': False,
#    'segmentation': [[814.9,
#      467.20000000000005,
#      954.3,
#      429.5,
#      937.3,
#      343.5,
#      796.4,
#      382.9,
#      802.5,
#      413.6,
#      799.0,
#      416.6,
#      801.2,
#      429.5,
#      806.1,
#      437.1,
#      812.3,
#      468.1]]},
#   {'area': 0,
#    'bbox': [534.0, 395.0, 124.0, 75.0],
#    'category_id': 34,
#    'color': '',
#    'id': 30,
#    'image_id': 8,
#    'iscrowd': False,
#    'segmentation': [[552.6,
#      469.79999999999995,
#      640.0,
#      448.1,
#      642.7,
#      430.6,
#      658.4,
#      429.0,
#      654.6,
#      408.5,
#      637.3,
#      410.9,
#      632.5,
#      394.5,
#      541.4,
#      415.5,
#      534.1,
#      420.6,
#      542.3,
#      465.4]]},
#   {'area': 0,
#    'bbox': [649.0, 352.0, 113.0, 186.0],
#    'category_id': 34,
#    'color': '',
#    'id': 31,
#    'image_id': 8,
#    'iscrowd': False,
#    'segmentation': [[649.9,
#      514.4,
#      716.6,
#      537.7,
#      762.0,
#      380.5,
#      758.9,
#      373.9,
#      735.6,
#      366.9,
#      734.1,
#      363.0,
#      727.1,
#      359.20000000000005,
#      716.2,
#      359.9,
#      691.8,
#      351.4,
#      648.3,
#      510.1]]},
#   {'area': 0,
#    'bbox': [920.0, 353.0, 112.0, 184.0],
#    'category_id': 34,
#    'color': '',
#    'id': 32,
#    'image_id': 9,
#    'iscrowd': False,
#    'segmentation': [[965.5,
#      537.3,
#      1027.8,
#      518.1,
#      1032.6,
#      507.9,
#      987.3,
#      352.9,
#      962.2,
#      356.6,
#      919.8,
#      375.20000000000005,
#      961.2,
#      536.4]]},
#   {'area': 0,
#    'bbox': [1022.0, 396.0, 122.0, 75.0],
#    'category_id': 34,
#    'color': '',
#    'id': 33,
#    'image_id': 9,
#    'iscrowd': False,
#    'segmentation': [[1134.4,
#      469.20000000000005,
#      1137.3,
#      465.6,
#      1144.4,
#      430.4,
#      1142.5,
#      417.70000000000005,
#      1048.7,
#      395.4,
#      1040.9,
#      410.29999999999995,
#      1025.1,
#      407.4,
#      1021.8,
#      429.1,
#      1039.0,
#      433.6,
#      1037.0,
#      444.9,
#      1131.1,
#      471.6]]},
#   {'area': 0,
#    'bbox': [691.0, 463.0, 112.0, 112.0],
#    'category_id': 34,
#    'color': '',
#    'id': 34,
#    'image_id': 10,
#    'iscrowd': False,
#    'segmentation': [[727.8,
#      572.4,
#      802.7,
#      506.4,
#      801.2,
#      490.1,
#      788.7,
#      470.29999999999995,
#      774.4,
#      463.29999999999995,
#      699.9,
#      529.3,
#      699.9,
#      546.7,
#      690.6,
#      554.9,
#      699.9,
#      572.0,
#      713.5,
#      565.0,
#      726.7,
#      575.5]]},
#   {'area': 0,
#    'bbox': [802.0, 352.0, 150.0, 189.0],
#    'category_id': 34,
#    'color': '',
#    'id': 35,
#    'image_id': 10,
#    'iscrowd': False,
#    'segmentation': [[895.6,
#      540.0,
#      951.9,
#      490.0,
#      860.3,
#      352.20000000000005,
#      822.2,
#      378.6,
#      824.6,
#      386.79999999999995,
#      801.7,
#      407.29999999999995,
#      893.6,
#      540.8]]},
#   {'area': 0,
#    'bbox': [729.0, 351.0, 148.0, 191.0],
#    'category_id': 34,
#    'color': '',
#    'id': 36,
#    'image_id': 11,
#    'iscrowd': False,
#    'segmentation': [[784.8,
#      541.5,
#      876.8,
#      410.0,
#      855.5,
#      377.79999999999995,
#      819.6,
#      350.70000000000005,
#      729.1,
#      487.0,
#      784.4,
#      542.3]]},
#   {'area': 0,
#    'bbox': [878.0, 463.0, 111.0, 113.0],
#    'category_id': 34,
#    'color': '',
#    'id': 37,
#    'image_id': 11,
#    'iscrowd': False,
#    'segmentation': [[957.1,
#      573.5,
#      964.8,
#      564.4,
#      980.4,
#      575.7,
#      988.5,
#      559.6,
#      978.9,
#      545.8,
#      979.8,
#      530.0,
#      908.1,
#      462.4,
#      887.6,
#      476.0,
#      877.4,
#      503.4,
#      955.1,
#      575.1]]},
#   {'area': 0,
#    'bbox': [945.0, 417.0, 116.0, 111.0],
#    'category_id': 34,
#    'color': '',
#    'id': 38,
#    'image_id': 12,
#    'iscrowd': False,
#    'segmentation': [[955.9,
#      523.4,
#      966.4,
#      514.1,
#      975.3,
#      528.1,
#      1057.6,
#      471.4,
#      1061.1,
#      461.29999999999995,
#      1055.7,
#      438.4,
#      1037.7,
#      417.1,
#      956.2,
#      473.1,
#      956.8,
#      494.70000000000005,
#      944.5,
#      507.9,
#      952.3,
#      523.7]]},
#   {'area': 0,
#    'bbox': [874.0, 543.0, 122.0, 72.0],
#    'category_id': 34,
#    'color': '',
#    'id': 39,
#    'image_id': 13,
#    'iscrowd': False,
#    'segmentation': [[878.3,
#      614.5,
#      976.5,
#      601.3,
#      979.6,
#      585.0,
#      996.3,
#      581.9,
#      993.6,
#      559.0,
#      974.9,
#      560.1,
#      972.6,
#      542.7,
#      876.4,
#      556.6,
#      873.7,
#      561.7,
#      877.2,
#      610.0]]},
#   {'area': 0,
#    'bbox': [682.0, 543.0, 123.0, 70.0],
#    'category_id': 34,
#    'color': '',
#    'id': 40,
#    'image_id': 14,
#    'iscrowd': False,
#    'segmentation': [[799.5,
#      613.4,
#      803.0,
#      603.7,
#      805.2,
#      557.9,
#      802.0,
#      556.3,
#      706.6,
#      543.1,
#      702.8,
#      557.7,
#      682.0,
#      557.9,
#      684.7,
#      584.1,
#      700.9,
#      584.9,
#      702.8,
#      600.2,
#      796.0,
#      612.9]]},
#   {'area': 0,
#    'bbox': [914.0, 451.0, 117.0, 102.0],
#    'category_id': 34,
#    'color': '',
#    'id': 41,
#    'image_id': 15,
#    'iscrowd': False,
#    'segmentation': [[947.0,
#      552.7,
#      1031.0,
#      500.6,
#      1028.4,
#      480.5,
#      1012.9,
#      450.79999999999995,
#      925.3,
#      499.9,
#      928.5,
#      518.1,
#      915.9,
#      528.1,
#      913.6,
#      534.5,
#      924.6,
#      548.5,
#      936.6,
#      542.3,
#      945.0,
#      553.3]]},
#   {'area': 0,
#    'bbox': [704.0, 281.0, 59.0, 156.0],
#    'category_id': 34,
#    'color': '',
#    'id': 42,
#    'image_id': 16,
#    'iscrowd': False,
#    'segmentation': [[720.0,
#      416.9,
#      734.3,
#      419.9,
#      734.6,
#      437.1,
#      751.5,
#      435.20000000000005,
#      752.6,
#      416.1,
#      763.4,
#      408.5,
#      751.0,
#      290.5,
#      745.6,
#      280.5,
#      708.7,
#      287.79999999999995,
#      703.8,
#      295.6,
#      719.6,
#      416.1]]},
#   {'area': 0,
#    'bbox': [917.0, 282.0, 58.0, 158.0],
#    'category_id': 34,
#    'color': '',
#    'id': 43,
#    'image_id': 17,
#    'iscrowd': False,
#    'segmentation': [[922.5,
#      410.9,
#      929.1,
#      414.6,
#      927.2,
#      435.1,
#      944.7,
#      440.5,
#      947.4,
#      419.70000000000005,
#      958.7,
#      418.70000000000005,
#      974.9,
#      291.20000000000005,
#      933.0,
#      281.70000000000005,
#      916.6,
#      406.9]]},
#   {'area': 0,
#    'bbox': [616.0, 317.0, 76.0, 135.0],
#    'category_id': 34,
#    'color': '',
#    'id': 44,
#    'image_id': 18,
#    'iscrowd': False,
#    'segmentation': [[644.1,
#      449.29999999999995,
#      644.9,
#      446.20000000000005,
#      660.4,
#      452.0,
#      692.2,
#      331.29999999999995,
#      646.8,
#      316.6,
#      615.8,
#      434.20000000000005,
#      629.3,
#      441.5,
#      631.7,
#      447.4,
#      643.3,
#      451.20000000000005]]},
#   {'area': 0,
#    'bbox': [863.0, 281.0, 133.0, 176.0],
#    'category_id': 34,
#    'color': '',
#    'id': 45,
#    'image_id': 18,
#    'iscrowd': False,
#    'segmentation': [[927.4,
#      456.1,
#      996.5,
#      318.29999999999995,
#      969.1,
#      297.70000000000005,
#      930.5,
#      280.9,
#      862.9,
#      418.4,
#      864.6,
#      423.4,
#      920.6,
#      457.0]]},
#   {'area': 0,
#    'bbox': [694.0, 345.0, 41.0, 246.0],
#    'category_id': 37,
#    'color': '',
#    'id': 46,
#    'image_id': 18,
#    'iscrowd': False,
#    'segmentation': [[715.6,
#      587.9,
#      722.0,
#      590.7,
#      732.6,
#      586.2,
#      735.3,
#      550.1,
#      727.5,
#      503.4,
#      730.1,
#      483.79999999999995,
#      718.5,
#      464.4,
#      717.7,
#      448.79999999999995,
#      724.3,
#      440.29999999999995,
#      715.8,
#      344.5,
#      694.1,
#      346.20000000000005,
#      701.1,
#      442.20000000000005,
#      708.1,
#      453.4,
#      704.9,
#      471.1,
#      703.9,
#      540.0,
#      709.0,
#      576.7]]},
#   {'area': 0,
#    'bbox': [904.0, 442.0, 172.0, 97.0],
#    'category_id': 28,
#    'color': '',
#    'id': 47,
#    'image_id': 18,
#    'iscrowd': False,
#    'segmentation': [[921.4,
#      538.4,
#      936.5,
#      533.5,
#      1022.2,
#      488.20000000000005,
#      1063.9,
#      487.6,
#      1074.6,
#      472.0,
#      1075.7,
#      458.0,
#      1074.5,
#      450.6,
#      1061.5,
#      465.79999999999995,
#      1055.1,
#      465.9,
#      1050.2,
#      462.20000000000005,
#      1063.9,
#      447.1,
#      1063.9,
#      442.1,
#      1052.0,
#      442.20000000000005,
#      1037.3,
#      448.4,
#      1031.5,
#      444.79999999999995,
#      1013.9,
#      472.0,
#      936.7,
#      502.5,
#      906.4,
#      518.5,
#      904.4,
#      527.7,
#      907.7,
#      535.7,
#      918.7,
#      539.3]]},
#   {'area': 0,
#    'bbox': [935.0, 359.0, 152.0, 107.0],
#    'category_id': 25,
#    'color': '',
#    'id': 48,
#    'image_id': 18,
#    'iscrowd': False,
#    'segmentation': [[958.0,
#      465.0,
#      969.3,
#      457.5,
#      979.3,
#      442.70000000000005,
#      993.8,
#      432.20000000000005,
#      1024.3,
#      405.5,
#      1084.2,
#      365.29999999999995,
#      1087.6,
#      359.4,
#      1082.0,
#      358.79999999999995,
#      1028.2,
#      393.79999999999995,
#      1006.4,
#      404.29999999999995,
#      969.7,
#      420.70000000000005,
#      962.7,
#      419.1,
#      938.2,
#      429.9,
#      934.9,
#      440.4,
#      941.4,
#      458.5,
#      956.5,
#      466.0]]},
#   {'area': 0,
#    'bbox': [676.0, 266.0, 163.0, 136.0],
#    'category_id': 34,
#    'color': '',
#    'id': 49,
#    'image_id': 19,
#    'iscrowd': False,
#    'segmentation': [[705.9,
#      401.4,
#      838.7,
#      340.79999999999995,
#      808.4,
#      265.9,
#      676.1,
#      330.0,
#      704.8,
#      402.9]]},
#   {'area': 0,
#    'bbox': [686.0, 472.0, 119.0, 99.0],
#    'category_id': 34,
#    'color': '',
#    'id': 50,
#    'image_id': 19,
#    'iscrowd': False,
#    'segmentation': [[763.0,
#      561.1,
#      782.3,
#      571.0,
#      804.9,
#      523.6,
#      707.5,
#      472.0,
#      699.0,
#      485.6,
#      693.1,
#      486.70000000000005,
#      686.2,
#      498.0,
#      689.6,
#      502.3,
#      686.2,
#      520.5,
#      758.7,
#      558.9]]},
#   {'area': 0,
#    'bbox': [757.0, 415.0, 179.0, 69.0],
#    'category_id': 28,
#    'color': '',
#    'id': 51,
#    'image_id': 19,
#    'iscrowd': False,
#    'segmentation': [[780.5,
#      467.4,
#      803.4,
#      457.70000000000005,
#      815.2,
#      457.70000000000005,
#      906.3,
#      482.70000000000005,
#      916.0,
#      480.6,
#      927.3,
#      483.79999999999995,
#      936.5,
#      471.9,
#      933.3,
#      462.20000000000005,
#      845.3,
#      441.79999999999995,
#      821.9,
#      439.1,
#      796.6,
#      414.79999999999995,
#      791.4,
#      420.5,
#      766.9,
#      419.4,
#      765.0,
#      422.4,
#      781.7,
#      438.5,
#      773.7,
#      446.1,
#      757.8,
#      432.9,
#      756.9,
#      435.6,
#      759.6,
#      450.4,
#      766.4,
#      461.20000000000005,
#      777.7,
#      467.4]]},
#   {'area': 0,
#    'bbox': [978.0, 331.0, 147.0, 119.0],
#    'category_id': 25,
#    'color': '',
#    'id': 52,
#    'image_id': 19,
#    'iscrowd': False,
#    'segmentation': [[1113.9,
#      445.29999999999995,
#      1124.7,
#      431.6,
#      1122.4,
#      415.20000000000005,
#      1044.5,
#      377.4,
#      983.7,
#      330.79999999999995,
#      977.6,
#      332.1,
#      977.6,
#      335.4,
#      1041.3,
#      383.20000000000005,
#      1078.8,
#      427.20000000000005,
#      1103.3,
#      450.20000000000005]]},
#   {'area': 0,
#    'bbox': [770.0, 570.0, 239.0, 50.0],
#    'category_id': 37,
#    'color': '',
#    'id': 53,
#    'image_id': 19,
#    'iscrowd': False,
#    'segmentation': [[778.4,
#      599.6,
#      798.4,
#      603.6,
#      874.0,
#      608.2,
#      907.7,
#      603.1,
#      918.5,
#      610.1,
#      1007.2,
#      619.9,
#      1008.6,
#      598.5,
#      921.7,
#      587.5,
#      907.8,
#      592.6,
#      893.8,
#      585.2,
#      843.7,
#      575.5,
#      777.0,
#      570.1,
#      769.6,
#      577.8,
#      774.3,
#      598.0]]},
#   {'area': 0,
#    'bbox': [555.0, 331.0, 148.0, 118.0],
#    'category_id': 25,
#    'color': '',
#    'id': 54,
#    'image_id': 20,
#    'iscrowd': False,
#    'segmentation': [[580.8,
#      445.5,
#      588.8,
#      440.20000000000005,
#      640.9,
#      384.29999999999995,
#      701.7,
#      337.1,
#      703.3,
#      331.9,
#      699.4,
#      330.6,
#      627.3,
#      379.79999999999995,
#      600.2,
#      395.6,
#      582.1,
#      402.1,
#      555.9,
#      418.29999999999995,
#      554.6,
#      430.9,
#      568.8,
#      449.5]]},
#   {'area': 0,
#    'bbox': [743.0, 415.0, 181.0, 68.0],
#    'category_id': 28,
#    'color': '',
#    'id': 55,
#    'image_id': 20,
#    'iscrowd': False,
#    'segmentation': [[758.5,
#      482.70000000000005,
#      842.4,
#      462.4,
#      865.4,
#      458.9,
#      879.6,
#      460.20000000000005,
#      900.3,
#      468.9,
#      914.5,
#      461.79999999999995,
#      922.0,
#      444.29999999999995,
#      924.2,
#      431.70000000000005,
#      906.1,
#      445.29999999999995,
#      899.0,
#      437.20000000000005,
#      914.2,
#      421.0,
#      910.6,
#      419.70000000000005,
#      886.7,
#      419.1,
#      880.9,
#      414.6,
#      861.5,
#      437.5,
#      844.7,
#      442.0,
#      748.6,
#      459.79999999999995,
#      742.5,
#      470.20000000000005,
#      747.2,
#      480.79999999999995]]},
#   {'area': 0,
#    'bbox': [672.0, 569.0, 237.0, 50.0],
#    'category_id': 37,
#    'color': '',
#    'id': 56,
#    'image_id': 20,
#    'iscrowd': False,
#    'segmentation': [[671.7,
#      599.3,
#      672.2,
#      618.8,
#      759.9,
#      610.7,
#      769.2,
#      603.2,
#      778.0,
#      602.9,
#      795.8,
#      607.4,
#      902.0,
#      602.3,
#      909.3,
#      588.4,
#      906.5,
#      569.4,
#      802.4,
#      580.8,
#      795.0,
#      587.5,
#      769.8,
#      594.0,
#      758.4,
#      587.9,
#      673.4,
#      598.2]]},
#   {'area': 0,
#    'bbox': [878.0, 471.0, 117.0, 100.0],
#    'category_id': 34,
#    'color': '',
#    'id': 57,
#    'image_id': 20,
#    'iscrowd': False,
#    'segmentation': [[900.5,
#      570.7,
#      993.3,
#      522.6,
#      995.5,
#      519.9,
#      988.1,
#      503.7,
#      992.6,
#      498.79999999999995,
#      985.7,
#      484.9,
#      980.8,
#      485.79999999999995,
#      974.3,
#      471.0,
#      880.9,
#      522.0,
#      878.2,
#      521.7,
#      879.7,
#      533.9,
#      898.4,
#      570.3]]},
#   {'area': 0,
#    'bbox': [841.0, 266.0, 163.0, 136.0],
#    'category_id': 34,
#    'color': '',
#    'id': 58,
#    'image_id': 20,
#    'iscrowd': False,
#    'segmentation': [[976.5,
#      400.5,
#      1004.0,
#      328.70000000000005,
#      869.0,
#      265.5,
#      841.1,
#      340.4,
#      974.5,
#      402.1]]},
#   {'area': 0,
#    'bbox': [818.0, 335.0, 220.0, 139.0],
#    'category_id': 37,
#    'color': '',
#    'id': 59,
#    'image_id': 21,
#    'iscrowd': False,
#    'segmentation': [[1027.8,
#      473.70000000000005,
#      1038.3,
#      455.79999999999995,
#      1032.0,
#      443.4,
#      942.8,
#      398.79999999999995,
#      916.0,
#      391.79999999999995,
#      905.5,
#      379.79999999999995,
#      827.2,
#      335.1,
#      818.2,
#      356.9,
#      895.1,
#      402.1,
#      906.8,
#      400.4,
#      925.8,
#      419.4,
#      985.1,
#      455.70000000000005,
#      1024.2,
#      473.6]]},
#   {'area': 0,
#    'bbox': [727.0, 523.0, 151.0, 127.0],
#    'category_id': 28,
#    'color': '',
#    'id': 60,
#    'image_id': 21,
#    'iscrowd': False,
#    'segmentation': [[864.9,
#      649.6,
#      866.9,
#      650.2,
#      877.6,
#      644.1,
#      877.2,
#      630.2,
#      810.0,
#      584.6,
#      785.1,
#      564.9,
#      775.7,
#      533.5,
#      767.6,
#      535.7,
#      754.0,
#      525.1,
#      742.7,
#      522.5,
#      751.4,
#      545.1,
#      741.1,
#      549.0,
#      731.1,
#      530.9,
#      727.2,
#      539.0,
#      730.4,
#      561.3,
#      734.6,
#      568.1,
#      768.6,
#      573.9,
#      814.8,
#      618.5,
#      861.1,
#      647.3]]},
#   {'area': 0,
#    'bbox': [651.0, 319.0, 39.0, 187.0],
#    'category_id': 25,
#    'color': '',
#    'id': 61,
#    'image_id': 21,
#    'iscrowd': False,
#    'segmentation': [[675.0,
#      505.9,
#      687.0,
#      499.6,
#      689.8,
#      481.9,
#      679.6,
#      417.6,
#      682.4,
#      321.29999999999995,
#      675.4,
#      319.4,
#      671.2,
#      408.29999999999995,
#      660.5,
#      456.29999999999995,
#      651.2,
#      469.29999999999995,
#      651.6,
#      494.9,
#      663.3,
#      505.4]]},
#   {'area': 0,
#    'bbox': [964.0, 484.0, 83.0, 128.0],
#    'category_id': 34,
#    'color': '',
#    'id': 62,
#    'image_id': 21,
#    'iscrowd': False,
#    'segmentation': [[1007.4,
#      611.6,
#      1047.5,
#      596.2,
#      1006.0,
#      484.0,
#      979.0,
#      487.20000000000005,
#      963.7,
#      505.4,
#      1003.7,
#      610.2]]},
#   {'area': 0,
#    'bbox': [636.0, 511.0, 113.0, 161.0],
#    'category_id': 34,
#    'color': '',
#    'id': 63,
#    'image_id': 21,
#    'iscrowd': False,
#    'segmentation': [[685.2,
#      672.1,
#      749.6,
#      655.2,
#      706.1,
#      510.4,
#      639.3,
#      530.5,
#      636.1,
#      541.7,
#      682.0,
#      672.1]]},
#   {'area': 0,
#    'bbox': [632.0, 484.0, 85.0, 127.0],
#    'category_id': 34,
#    'color': '',
#    'id': 64,
#    'image_id': 22,
#    'iscrowd': False,
#    'segmentation': [[673.5,
#      611.2,
#      717.5,
#      505.1,
#      704.2,
#      495.9,
#      704.7,
#      491.0,
#      689.2,
#      486.29999999999995,
#      686.5,
#      489.20000000000005,
#      673.0,
#      483.79999999999995,
#      635.7,
#      583.1,
#      632.2,
#      596.7,
#      669.5,
#      611.4]]},
#   {'area': 0,
#    'bbox': [931.0, 512.0, 113.0, 162.0],
#    'category_id': 34,
#    'color': '',
#    'id': 65,
#    'image_id': 22,
#    'iscrowd': False,
#    'segmentation': [[995.8,
#      674.2,
#      1044.0,
#      540.9,
#      1041.8,
#      531.9,
#      975.9,
#      511.5,
#      942.0,
#      612.3,
#      931.0,
#      650.9,
#      933.9,
#      658.6,
#      993.0,
#      673.2]]},
#   {'area': 0,
#    'bbox': [802.0, 524.0, 150.0, 126.0],
#    'category_id': 28,
#    'color': '',
#    'id': 66,
#    'image_id': 22,
#    'iscrowd': False,
#    'segmentation': [[811.4,
#      649.9,
#      814.4,
#      649.9,
#      842.2,
#      634.2,
#      890.4,
#      592.9,
#      902.7,
#      579.2,
#      921.1,
#      572.7,
#      938.2,
#      572.2,
#      948.1,
#      565.2,
#      952.6,
#      541.9,
#      948.5,
#      529.3,
#      938.9,
#      547.5,
#      936.6,
#      549.3,
#      928.3,
#      544.6,
#      937.5,
#      523.9,
#      928.1,
#      523.7,
#      910.7,
#      535.6,
#      905.3,
#      533.6,
#      895.2,
#      561.2,
#      826.4,
#      611.9,
#      802.2,
#      633.4,
#      802.0,
#      642.6,
#      808.7,
#      648.7]]},
#   {'area': 0,
#    'bbox': [643.0, 334.0, 219.0, 141.0],
#    'category_id': 37,
#    'color': '',
#    'id': 67,
#    'image_id': 22,
#    'iscrowd': False,
#    'segmentation': [[656.2,
#      473.79999999999995,
#      684.9,
#      462.6,
#      749.4,
#      423.0,
#      756.0,
#      412.1,
#      771.1,
#      400.5,
#      783.5,
#      401.6,
#      861.9,
#      356.6,
#      853.7,
#      334.1,
#      774.6,
#      379.1,
#      768.4,
#      389.6,
#      697.7,
#      416.79999999999995,
#      643.8,
#      447.4,
#      642.6,
#      454.4,
#      653.9,
#      475.4]]},
#   {'area': 0,
#    'bbox': [991.0, 320.0, 35.0, 187.0],
#    'category_id': 25,
#    'color': '',
#    'id': 68,
#    'image_id': 22,
#    'iscrowd': False,
#    'segmentation': [[995.0,
#      501.0,
#      999.2,
#      504.2,
#      1014.4,
#      506.8,
#      1025.8,
#      498.1,
#      1026.4,
#      471.9,
#      1010.6,
#      416.6,
#      1003.1,
#      321.79999999999995,
#      997.9,
#      319.6,
#      1001.1,
#      406.6,
#      998.4,
#      456.20000000000005,
#      991.8,
#      464.4,
#      991.0,
#      498.20000000000005]]},
#   {'area': 0,
#    'bbox': [557.0, 482.0, 97.0, 160.0],
#    'category_id': 34,
#    'color': '',
#    'id': 69,
#    'image_id': 23,
#    'iscrowd': False,
#    'segmentation': [[583.4,
#      640.6,
#      585.4,
#      641.8,
#      645.9,
#      638.3,
#      654.1,
#      632.5,
#      632.3,
#      481.9,
#      557.4,
#      491.20000000000005,
#      580.7,
#      639.7]]},
#   {'area': 0,
#    'bbox': [939.0, 498.0, 89.0, 130.0],
#    'category_id': 34,
#    'color': '',
#    'id': 70,
#    'image_id': 23,
#    'iscrowd': False,
#    'segmentation': [[981.1,
#      624.7,
#      1028.3,
#      520.9,
#      985.3,
#      497.9,
#      940.1,
#      598.8,
#      939.1,
#      606.3,
#      950.4,
#      618.9,
#      959.8,
#      623.7,
#      965.6,
#      622.8,
#      980.5,
#      627.9]]},
#   {'area': 0,
#    'bbox': [653.0, 498.0, 90.0, 131.0],
#    'category_id': 34,
#    'color': '',
#    'id': 71,
#    'image_id': 24,
#    'iscrowd': False,
#    'segmentation': [[701.0,
#      629.1,
#      720.7,
#      625.3,
#      735.9,
#      614.4,
#      743.3,
#      606.6,
#      695.1,
#      498.0,
#      653.2,
#      521.3,
#      699.0,
#      628.4]]},
#   {'area': 0,
#    'bbox': [1026.0, 479.0, 96.0, 165.0],
#    'category_id': 34,
#    'color': '',
#    'id': 72,
#    'image_id': 24,
#    'iscrowd': False,
#    'segmentation': [[1037.2,
#      637.0,
#      1096.4,
#      643.7,
#      1121.5,
#      493.4,
#      1051.0,
#      479.29999999999995,
#      1026.1,
#      629.7]]},
#   {'area': 0,
#    'bbox': [942.0, 542.0, 116.0, 92.0],
#    'category_id': 34,
#    'color': '',
#    'id': 73,
#    'image_id': 25,
#    'iscrowd': False,
#    'segmentation': [[1041.2,
#      633.3,
#      1046.6,
#      619.3,
#      1052.0,
#      621.6,
#      1057.1,
#      607.3,
#      1052.8,
#      602.2,
#      1058.4,
#      586.8,
#      959.8,
#      541.4,
#      941.7,
#      590.4,
#      1039.6,
#      634.0]]},
#   {'area': 0,
#    'bbox': [909.0, 314.0, 164.0, 152.0],
#    'category_id': 34,
#    'color': '',
#    'id': 74,
#    'image_id': 25,
#    'iscrowd': False,
#    'segmentation': [[1039.8,
#      458.6,
#      1052.1,
#      441.0,
#      1073.5,
#      401.4,
#      948.9,
#      313.6,
#      909.2,
#      383.5,
#      1032.7,
#      465.70000000000005]]},
#   {'area': 0,
#    'bbox': [608.0, 315.0, 164.0, 152.0],
#    'category_id': 34,
#    'color': '',
#    'id': 75,
#    'image_id': 26,
#    'iscrowd': False,
#    'segmentation': [[648.5,
#      465.79999999999995,
#      768.8,
#      385.29999999999995,
#      772.0,
#      381.4,
#      732.2,
#      314.1,
#      608.0,
#      397.29999999999995,
#      624.2,
#      433.79999999999995,
#      645.2,
#      466.79999999999995]]},
#   {'area': 0,
#    'bbox': [622.0, 543.0, 116.0, 90.0],
#    'category_id': 34,
#    'color': '',
#    'id': 76,
#    'image_id': 26,
#    'iscrowd': False,
#    'segmentation': [[639.9,
#      632.6,
#      738.3,
#      591.4,
#      736.7,
#      580.9,
#      720.5,
#      542.6,
#      626.5,
#      584.9,
#      621.9,
#      583.3,
#      627.5,
#      603.0,
#      622.4,
#      606.7,
#      627.5,
#      620.2,
#      632.4,
#      619.4,
#      639.1,
#      632.9]]},
#   {'area': 0,
#    'bbox': [535.0, 443.0, 161.0, 163.0],
#    'category_id': 34,
#    'color': '',
#    'id': 77,
#    'image_id': 27,
#    'iscrowd': False,
#    'segmentation': [[650.7,
#      605.9,
#      695.9,
#      544.4,
#      582.3,
#      442.9,
#      535.2,
#      504.8,
#      647.5,
#      606.4]]},
#   {'area': 0,
#    'bbox': [912.0, 326.0, 81.0, 131.0],
#    'category_id': 34,
#    'color': '',
#    'id': 78,
#    'image_id': 27,
#    'iscrowd': False,
#    'segmentation': [[950.6,
#      456.70000000000005,
#      992.9,
#      438.9,
#      955.2,
#      325.5,
#      935.3,
#      327.6,
#      923.7,
#      333.0,
#      911.6,
#      345.4,
#      948.7,
#      455.6]]},
#   {'area': 0,
#    'bbox': [687.0, 325.0, 82.0, 132.0],
#    'category_id': 34,
#    'color': '',
#    'id': 79,
#    'image_id': 28,
#    'iscrowd': False,
#    'segmentation': [[686.2,
#      439.4,
#      732.1,
#      456.9,
#      769.0,
#      345.9,
#      756.3,
#      337.20000000000005,
#      755.8,
#      331.29999999999995,
#      743.9,
#      326.70000000000005,
#      739.9,
#      331.29999999999995,
#      725.6,
#      324.79999999999995,
#      688.1,
#      436.70000000000005]]},
#   {'area': 0,
#    'bbox': [982.0, 443.0, 161.0, 161.0],
#    'category_id': 34,
#    'color': '',
#    'id': 80,
#    'image_id': 28,
#    'iscrowd': False,
#    'segmentation': [[1033.7,
#      603.4,
#      1142.7,
#      507.3,
#      1141.6,
#      498.4,
#      1099.1,
#      443.0,
#      981.7,
#      545.9,
#      1030.9,
#      604.5]]},
#   {'area': 0,
#    'bbox': [881.0, 508.0, 118.0, 90.0],
#    'category_id': 34,
#    'color': '',
#    'id': 81,
#    'image_id': 29,
#    'iscrowd': False,
#    'segmentation': [[898.0,
#      597.5,
#      997.7,
#      567.9,
#      998.5,
#      556.3,
#      987.8,
#      507.8,
#      887.0,
#      538.6,
#      883.2,
#      538.6,
#      886.4,
#      561.5,
#      880.4,
#      564.7,
#      885.5,
#      581.7,
#      890.1,
#      580.4,
#      894.4,
#      598.0]]},
#   {'area': 0,
#    'bbox': [858.0, 375.0, 114.0, 128.0],
#    'category_id': 34,
#    'color': '',
#    'id': 82,
#    'image_id': 30,
#    'iscrowd': False,
#    'segmentation': [[946.2,
#      502.1,
#      956.3,
#      487.5,
#      960.3,
#      489.79999999999995,
#      968.0,
#      476.29999999999995,
#      964.9,
#      470.9,
#      971.9,
#      458.20000000000005,
#      971.9,
#      453.1,
#      956.5,
#      441.29999999999995,
#      892.9,
#      382.20000000000005,
#      886.7,
#      374.20000000000005,
#      858.4,
#      423.5,
#      945.0,
#      503.2]]},
#   {'area': 0,
#    'bbox': [830.0, 579.0, 113.0, 71.0],
#    'category_id': 34,
#    'color': '',
#    'id': 83,
#    'image_id': 31,
#    'iscrowd': False,
#    'segmentation': [[834.2,
#      650.4,
#      940.3,
#      636.0,
#      937.5,
#      619.7,
#      943.1,
#      619.2,
#      941.7,
#      600.1,
#      936.1,
#      600.6,
#      934.3,
#      579.2,
#      829.5,
#      595.9,
#      832.8,
#      647.2]]},
#   {'area': 0,
#    'bbox': [741.0, 480.0, 115.0, 74.0],
#    'category_id': 34,
#    'color': '',
#    'id': 84,
#    'image_id': 32,
#    'iscrowd': False,
#    'segmentation': [[747.9,
#      553.8,
#      851.9,
#      539.8,
#      851.4,
#      519.6,
#      856.2,
#      519.8,
#      856.2,
#      500.79999999999995,
#      849.1,
#      498.4,
#      848.8,
#      479.9,
#      746.2,
#      495.5,
#      740.7,
#      494.5,
#      745.9,
#      554.3]]},
#   {'area': 0,
#    'bbox': [634.0, 332.0, 51.0, 141.0],
#    'category_id': 34,
#    'color': '',
#    'id': 85,
#    'image_id': 33,
#    'iscrowd': False,
#    'segmentation': [[636.0,
#      464.29999999999995,
#      649.5,
#      468.0,
#      651.0,
#      472.1,
#      660.4,
#      473.0,
#      665.8,
#      468.20000000000005,
#      680.3,
#      468.0,
#      685.4,
#      335.9,
#      638.0,
#      331.79999999999995,
#      633.9,
#      462.79999999999995]]},
#   {'area': 0,
#    'bbox': [743.0, 499.0, 119.0, 112.0],
#    'category_id': 34,
#    'color': '',
#    'id': 86,
#    'image_id': 34,
#    'iscrowd': False,
#    'segmentation': [[767.5,
#      609.0,
#      862.5,
#      551.1,
#      855.4,
#      533.0,
#      859.6,
#      529.7,
#      853.5,
#      515.2,
#      848.0,
#      517.5,
#      838.9,
#      499.0,
#      743.2,
#      559.2,
#      765.5,
#      610.9]]},
#   {'area': 0,
#    'bbox': [652.0, 407.0, 166.0, 181.0],
#    'category_id': 9,
#    'color': '',
#    'id': 87,
#    'image_id': 35,
#    'iscrowd': False,
#    'segmentation': [[811.3,
#      560.1,
#      789.0,
#      484.6,
#      789.0,
#      478.79999999999995,
#      777.6,
#      443.20000000000005,
#      782.7,
#      442.0,
#      781.5,
#      432.70000000000005,
#      767.9,
#      424.4,
#      768.6,
#      418.6,
#      760.0,
#      407.20000000000005,
#      756.1,
#      407.6,
#      749.9,
#      419.4,
#      738.5,
#      417.4,
#      737.0,
#      410.0,
#      731.1,
#      412.70000000000005,
#      731.9,
#      426.79999999999995,
#      722.5,
#      436.20000000000005,
#      685.8,
#      434.20000000000005,
#      665.8,
#      436.6,
#      651.8,
#      449.9,
#      653.3,
#      454.9,
#      656.5,
#      455.70000000000005,
#      666.2,
#      495.6,
#      707.7,
#      484.29999999999995,
#      718.6,
#      486.6,
#      723.7,
#      513.2,
#      736.2,
#      530.8,
#      742.5,
#      532.7,
#      760.0,
#      527.7,
#      774.5,
#      576.5,
#      779.2,
#      578.9,
#      784.7,
#      586.3,
#      801.5,
#      583.9,
#      804.2,
#      587.9,
#      817.1,
#      584.3,
#      818.3,
#      563.6,
#      814.4,
#      560.5]]},
#   {'area': 0,
#    'bbox': [999.0, 374.0, 74.0, 130.0],
#    'category_id': 34,
#    'color': '',
#    'id': 88,
#    'image_id': 35,
#    'iscrowd': False,
#    'segmentation': [[1072.9,
#      486.79999999999995,
#      1045.7,
#      376.0,
#      1043.3,
#      374.4,
#      1002.3,
#      387.70000000000005,
#      998.5,
#      391.79999999999995,
#      1026.4,
#      502.0,
#      1031.6,
#      504.2,
#      1038.1,
#      504.2,
#      1042.5,
#      500.4,
#      1047.1,
#      503.9,
#      1054.4,
#      502.5,
#      1060.9,
#      493.9,
#      1073.1,
#      490.29999999999995]]},
#   {'area': 0,
#    'bbox': [616.0, 481.0, 80.0, 160.0],
#    'category_id': 34,
#    'color': '',
#    'id': 89,
#    'image_id': 35,
#    'iscrowd': False,
#    'segmentation': [[696.3,
#      633.6,
#      692.0,
#      490.1,
#      665.8,
#      496.70000000000005,
#      661.5,
#      480.70000000000005,
#      620.5,
#      482.29999999999995,
#      615.8,
#      490.5,
#      622.0,
#      637.1,
#      633.0,
#      640.6,
#      691.6,
#      641.0,
#      695.5,
#      635.9]]},
#   {'area': 0,
#    'bbox': [589.0, 291.0, 136.0, 185.0],
#    'category_id': 22,
#    'color': '',
#    'id': 90,
#    'image_id': 35,
#    'iscrowd': False,
#    'segmentation': [[639.8,
#      473.5,
#      721.5,
#      349.6,
#      723.4,
#      323.79999999999995,
#      717.9,
#      316.70000000000005,
#      725.0,
#      304.6,
#      709.3,
#      291.29999999999995,
#      701.5,
#      303.4,
#      691.0,
#      299.5,
#      667.1,
#      311.6,
#      588.9,
#      436.29999999999995,
#      594.0,
#      448.5,
#      605.4,
#      462.5,
#      622.6,
#      472.29999999999995,
#      631.9,
#      475.79999999999995,
#      636.6,
#      475.0]]},
#   {'area': 0,
#    'bbox': [872.0, 477.0, 82.0, 197.0],
#    'category_id': 28,
#    'color': '',
#    'id': 91,
#    'image_id': 35,
#    'iscrowd': False,
#    'segmentation': [[952.4,
#      652.7,
#      928.5,
#      556.5,
#      938.3,
#      508.0,
#      936.7,
#      497.9,
#      932.0,
#      490.4,
#      924.6,
#      484.20000000000005,
#      900.8,
#      476.4,
#      898.0,
#      483.79999999999995,
#      910.9,
#      505.7,
#      899.6,
#      515.9,
#      880.4,
#      489.70000000000005,
#      877.3,
#      494.70000000000005,
#      875.4,
#      529.5,
#      871.4,
#      538.9,
#      876.1,
#      547.9,
#      881.2,
#      548.7,
#      901.9,
#      566.3,
#      899.6,
#      573.3,
#      904.7,
#      585.8,
#      905.5,
#      604.6,
#      912.1,
#      613.2,
#      910.5,
#      638.2,
#      914.4,
#      649.9,
#      915.6,
#      671.8,
#      928.9,
#      674.2,
#      941.0,
#      671.8,
#      948.8,
#      665.0,
#      954.2,
#      654.4]]},
#   {'area': 0,
#    'bbox': [796.0, 573.0, 160.0, 80.0],
#    'category_id': 34,
#    'color': '',
#    'id': 92,
#    'image_id': 36,
#    'iscrowd': False,
#    'segmentation': [[953.8,
#      647.8,
#      956.2,
#      573.4,
#      809.1,
#      574.8,
#      807.4,
#      605.2,
#      795.5,
#      610.6,
#      795.5,
#      618.7,
#      806.6,
#      625.3,
#      807.2,
#      652.7,
#      950.2,
#      650.5]]},
#   {'area': 0,
#    'bbox': [988.0, 567.0, 126.0, 72.0],
#    'category_id': 34,
#    'color': '',
#    'id': 93,
#    'image_id': 36,
#    'iscrowd': False,
#    'segmentation': [[1094.4,
#      566.3,
#      988.1,
#      586.4,
#      994.9,
#      635.7,
#      996.9,
#      638.7,
#      1000.1,
#      639.1,
#      1100.5,
#      619.9,
#      1103.7,
#      616.3,
#      1099.8,
#      602.2,
#      1111.6,
#      597.7,
#      1114.3,
#      593.2,
#      1112.5,
#      585.5,
#      1107.7,
#      582.3,
#      1096.7,
#      584.6,
#      1094.2,
#      567.8]]},
#   {'area': 0,
#    'bbox': [673.0, 331.0, 198.0, 125.0],
#    'category_id': 28,
#    'color': '',
#    'id': 94,
#    'image_id': 36,
#    'iscrowd': False,
#    'segmentation': [[868.8,
#      436.6,
#      871.0,
#      427.1,
#      869.1,
#      411.6,
#      862.3,
#      393.20000000000005,
#      845.2,
#      385.6,
#      802.8,
#      390.20000000000005,
#      803.9,
#      386.70000000000005,
#      720.6,
#      338.29999999999995,
#      699.4,
#      331.0,
#      688.2,
#      335.4,
#      675.8,
#      348.1,
#      672.5,
#      366.0,
#      675.8,
#      369.6,
#      689.1,
#      369.79999999999995,
#      709.2,
#      377.20000000000005,
#      715.7,
#      384.0,
#      730.6,
#      384.79999999999995,
#      743.4,
#      391.0,
#      748.8,
#      398.9,
#      765.9,
#      403.20000000000005,
#      778.9,
#      414.4,
#      784.4,
#      411.9,
#      798.2,
#      438.5,
#      795.8,
#      445.0,
#      810.1,
#      454.5,
#      813.7,
#      448.79999999999995,
#      827.0,
#      454.5,
#      849.2,
#      456.4,
#      851.1,
#      455.1,
#      851.7,
#      453.70000000000005,
#      831.9,
#      430.9,
#      847.9,
#      416.79999999999995,
#      850.3,
#      416.79999999999995,
#      866.1,
#      439.1]]},
#   {'area': 0,
#    'bbox': [916.0, 283.0, 139.0, 235.0],
#    'category_id': 23,
#    'color': '',
#    'id': 95,
#    'image_id': 36,
#    'iscrowd': False,
#    'segmentation': [[950.6,
#      519.6,
#      993.7,
#      464.1,
#      1005.8,
#      463.29999999999995,
#      1021.8,
#      430.9,
#      1022.2,
#      421.9,
#      1055.4,
#      303.0,
#      1054.6,
#      293.6,
#      1051.5,
#      285.79999999999995,
#      1048.0,
#      282.70000000000005,
#      1041.7,
#      292.9,
#      994.8,
#      400.0,
#      995.6,
#      405.5,
#      988.6,
#      414.1,
#      968.2,
#      454.70000000000005,
#      933.4,
#      484.4,
#      917.0,
#      505.9,
#      915.9,
#      513.3,
#      919.4,
#      516.9,
#      950.3,
#      517.6]]},
#   {'area': 0,
#    'bbox': [669.0, 452.0, 112.0, 184.0],
#    'category_id': 22,
#    'color': '',
#    'id': 96,
#    'image_id': 36,
#    'iscrowd': False,
#    'segmentation': [[778.3,
#      594.6,
#      729.0,
#      452.0,
#      710.7,
#      455.29999999999995,
#      679.8,
#      468.9,
#      669.4,
#      481.6,
#      720.1,
#      622.3,
#      741.2,
#      636.4,
#      760.9,
#      633.6,
#      768.0,
#      629.8,
#      772.6,
#      623.7,
#      781.1,
#      595.1]]},
#   {'area': 0,
#    'bbox': [723.0, 573.0, 152.0, 78.0],
#    'category_id': 34,
#    'color': '',
#    'id': 97,
#    'image_id': 37,
#    'iscrowd': False,
#    'segmentation': [[727.7,
#      649.6,
#      870.3,
#      651.3,
#      872.2,
#      649.6,
#      871.9,
#      627.1,
#      875.2,
#      623.3,
#      874.6,
#      607.8,
#      871.9,
#      606.7,
#      871.9,
#      574.7,
#      725.8,
#      573.4,
#      723.1,
#      580.1,
#      726.1,
#      648.8]]},
#   {'area': 0,
#    'bbox': [573.0, 566.0, 119.0, 73.0],
#    'category_id': 34,
#    'color': '',
#    'id': 98,
#    'image_id': 37,
#    'iscrowd': False,
#    'segmentation': [[684.0,
#      638.3,
#      692.3,
#      589.3,
#      691.0,
#      586.4,
#      586.7,
#      566.4,
#      585.0,
#      566.8,
#      582.4,
#      583.6,
#      575.2,
#      582.8,
#      573.2,
#      599.6,
#      580.1,
#      601.5,
#      577.9,
#      618.7,
#      684.4,
#      639.6]]},
#   {'area': 0,
#    'bbox': [623.0, 283.0, 141.0, 236.0],
#    'category_id': 23,
#    'color': '',
#    'id': 99,
#    'image_id': 37,
#    'iscrowd': False,
#    'segmentation': [[764.5,
#      513.0,
#      752.8,
#      486.5,
#      739.9,
#      483.70000000000005,
#      712.9,
#      459.9,
#      686.8,
#      407.1,
#      682.1,
#      390.29999999999995,
#      635.9,
#      287.9,
#      629.3,
#      283.20000000000005,
#      623.0,
#      300.4,
#      654.7,
#      418.0,
#      665.6,
#      452.4,
#      680.1,
#      465.0,
#      733.3,
#      518.9,
#      754.8,
#      518.9,
#      763.0,
#      515.8]]},
#   {'area': 0,
#    'bbox': [808.0, 331.0, 199.0, 127.0],
#    'category_id': 28,
#    'color': '',
#    'id': 100,
#    'image_id': 37,
#    'iscrowd': False,
#    'segmentation': [[880.2,
#      440.1,
#      893.9,
#      413.1,
#      901.0,
#      413.79999999999995,
#      914.4,
#      403.0,
#      929.7,
#      397.79999999999995,
#      944.3,
#      386.70000000000005,
#      962.3,
#      383.79999999999995,
#      974.6,
#      375.29999999999995,
#      994.5,
#      369.1,
#      1004.3,
#      370.1,
#      1006.6,
#      364.6,
#      1004.3,
#      351.9,
#      995.2,
#      337.5,
#      983.4,
#      331.29999999999995,
#      970.1,
#      333.9,
#      919.3,
#      361.0,
#      880.5,
#      384.1,
#      875.9,
#      389.29999999999995,
#      831.3,
#      385.70000000000005,
#      814.4,
#      396.5,
#      808.2,
#      421.29999999999995,
#      810.1,
#      437.20000000000005,
#      812.7,
#      438.79999999999995,
#      830.0,
#      415.4,
#      847.6,
#      429.1,
#      828.4,
#      455.1,
#      830.0,
#      457.4,
#      844.3,
#      458.4,
#      864.9,
#      449.29999999999995,
#      872.4,
#      454.5,
#      883.8,
#      443.70000000000005]]},
#   {'area': 0,
#    'bbox': [900.0, 454.0, 111.0, 182.0],
#    'category_id': 22,
#    'color': '',
#    'id': 101,
#    'image_id': 37,
#    'iscrowd': False,
#    'segmentation': [[959.3,
#      621.0,
#      1010.9,
#      478.29999999999995,
#      1000.8,
#      468.5,
#      968.3,
#      455.6,
#      954.2,
#      454.1,
#      949.6,
#      456.0,
#      899.9,
#      594.0,
#      905.8,
#      624.5,
#      919.8,
#      634.3,
#      939.0,
#      636.2,
#      958.5,
#      623.3]]},
#   {'area': 0,
#    'bbox': [740.0, 491.0, 95.0, 124.0],
#    'category_id': 34,
#    'color': '',
#    'id': 102,
#    'image_id': 38,
#    'iscrowd': False,
#    'segmentation': [[784.8,
#      610.8,
#      834.6,
#      517.7,
#      829.4,
#      507.3,
#      792.0,
#      490.29999999999995,
#      788.7,
#      492.6,
#      740.2,
#      587.4,
#      744.1,
#      597.5,
#      751.2,
#      601.4,
#      750.9,
#      610.5,
#      763.3,
#      615.4,
#      769.5,
#      607.6,
#      781.5,
#      612.8]]},
#   {'area': 0,
#    'bbox': [868.0, 331.0, 164.0, 122.0],
#    'category_id': 34,
#    'color': '',
#    'id': 103,
#    'image_id': 38,
#    'iscrowd': False,
#    'segmentation': [[1009.4,
#      453.1,
#      1015.7,
#      424.1,
#      1023.0,
#      427.1,
#      1031.7,
#      412.1,
#      1029.0,
#      405.29999999999995,
#      1021.9,
#      403.4,
#      1027.1,
#      369.5,
#      886.7,
#      330.70000000000005,
#      884.8,
#      332.6,
#      867.5,
#      411.29999999999995,
#      1006.4,
#      452.6]]},
#   {'area': 0,
#    'bbox': [925.0, 552.0, 191.0, 120.0],
#    'category_id': 28,
#    'color': '',
#    'id': 104,
#    'image_id': 38,
#    'iscrowd': False,
#    'segmentation': [[1108.3,
#      644.6,
#      1090.6,
#      641.3,
#      1074.6,
# ...
#    'height': 1050,
#    'id': 934,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Other\\H_7321.11-0000_03_767.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_03_768.png',
#    'height': 1050,
#    'id': 935,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Other\\H_7321.11-0000_03_768.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_03_769.png',
#    'height': 1050,
#    'id': 936,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Other\\H_7321.11-0000_03_769.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_03_770.png',
#    'height': 1050,
#    'id': 937,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Other\\H_7321.11-0000_03_770.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_682.png',
#    'height': 1050,
#    'id': 938,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_04_682.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_683.png',
#    'height': 1050,
#    'id': 939,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_04_683.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_684.png',
#    'height': 1050,
#    'id': 940,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_04_684.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_685.png',
#    'height': 1050,
#    'id': 941,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_04_685.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_686.png',
#    'height': 1050,
#    'id': 942,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_04_686.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_687.png',
#    'height': 1050,
#    'id': 943,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_04_687.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_688.png',
#    'height': 1050,
#    'id': 944,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_04_688.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_721.png',
#    'height': 1050,
#    'id': 945,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Other\\H_7321.11-0000_04_721.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_722.png',
#    'height': 1050,
#    'id': 946,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Other\\H_7321.11-0000_04_722.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_723.png',
#    'height': 1050,
#    'id': 947,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Other\\H_7321.11-0000_04_723.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_724.png',
#    'height': 1050,
#    'id': 948,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Other\\H_7321.11-0000_04_724.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_725.png',
#    'height': 1050,
#    'id': 949,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Other\\H_7321.11-0000_04_725.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_726.png',
#    'height': 1050,
#    'id': 950,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Other\\H_7321.11-0000_04_726.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_742.png',
#    'height': 1050,
#    'id': 951,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Default\\H_7321.11-0000_04_742.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_743.png',
#    'height': 1050,
#    'id': 952,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Default\\H_7321.11-0000_04_743.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_744.png',
#    'height': 1050,
#    'id': 953,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Default\\H_7321.11-0000_04_744.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_745.png',
#    'height': 1050,
#    'id': 954,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Default\\H_7321.11-0000_04_745.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_746.png',
#    'height': 1050,
#    'id': 955,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Default\\H_7321.11-0000_04_746.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_762.png',
#    'height': 1050,
#    'id': 956,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Other\\H_7321.11-0000_04_762.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_763.png',
#    'height': 1050,
#    'id': 957,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Other\\H_7321.11-0000_04_763.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_764.png',
#    'height': 1050,
#    'id': 958,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Other\\H_7321.11-0000_04_764.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_765.png',
#    'height': 1050,
#    'id': 959,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Other\\H_7321.11-0000_04_765.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_04_766.png',
#    'height': 1050,
#    'id': 960,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Other\\H_7321.11-0000_04_766.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_682.png',
#    'height': 1050,
#    'id': 961,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_05_682.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_683.png',
#    'height': 1050,
#    'id': 962,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_05_683.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_684.png',
#    'height': 1050,
#    'id': 963,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_05_684.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_685.png',
#    'height': 1050,
#    'id': 964,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_05_685.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_686.png',
#    'height': 1050,
#    'id': 965,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_05_686.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_687.png',
#    'height': 1050,
#    'id': 966,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_05_687.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_688.png',
#    'height': 1050,
#    'id': 967,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_05_688.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_721.png',
#    'height': 1050,
#    'id': 968,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Other\\H_7321.11-0000_05_721.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_722.png',
#    'height': 1050,
#    'id': 969,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Other\\H_7321.11-0000_05_722.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_723.png',
#    'height': 1050,
#    'id': 970,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Other\\H_7321.11-0000_05_723.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_724.png',
#    'height': 1050,
#    'id': 971,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Other\\H_7321.11-0000_05_724.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_725.png',
#    'height': 1050,
#    'id': 972,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Other\\H_7321.11-0000_05_725.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_726.png',
#    'height': 1050,
#    'id': 973,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Other\\H_7321.11-0000_05_726.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_742.png',
#    'height': 1050,
#    'id': 974,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Default\\H_7321.11-0000_05_742.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_743.png',
#    'height': 1050,
#    'id': 975,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Default\\H_7321.11-0000_05_743.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_744.png',
#    'height': 1050,
#    'id': 976,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Default\\H_7321.11-0000_05_744.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_745.png',
#    'height': 1050,
#    'id': 977,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Default\\H_7321.11-0000_05_745.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_746.png',
#    'height': 1050,
#    'id': 978,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Default\\H_7321.11-0000_05_746.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_762.png',
#    'height': 1050,
#    'id': 979,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Other\\H_7321.11-0000_05_762.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_763.png',
#    'height': 1050,
#    'id': 980,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Other\\H_7321.11-0000_05_763.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_764.png',
#    'height': 1050,
#    'id': 981,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Other\\H_7321.11-0000_05_764.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_765.png',
#    'height': 1050,
#    'id': 982,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Other\\H_7321.11-0000_05_765.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_05_766.png',
#    'height': 1050,
#    'id': 983,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Single_Other\\H_7321.11-0000_05_766.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_06_683.png',
#    'height': 1050,
#    'id': 984,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_06_683.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_06_684.png',
#    'height': 1050,
#    'id': 985,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_06_684.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_06_685.png',
#    'height': 1050,
#    'id': 986,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_06_685.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_06_686.png',
#    'height': 1050,
#    'id': 987,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_06_686.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_06_687.png',
#    'height': 1050,
#    'id': 988,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_06_687.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_06_688.png',
#    'height': 1050,
#    'id': 989,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_06_688.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_06_689.png',
#    'height': 1050,
#    'id': 990,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_06_689.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_06_690.png',
#    'height': 1050,
#    'id': 991,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_06_690.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_06_691.png',
#    'height': 1050,
#    'id': 992,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_06_691.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_06_692.png',
#    'height': 1050,
#    'id': 993,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_06_692.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_06_693.png',
#    'height': 1050,
#    'id': 994,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Categories\\H_7321.11-0000_06_693.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_06_726.png',
#    'height': 1050,
#    'id': 995,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Other\\H_7321.11-0000_06_726.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_06_727.png',
#    'height': 1050,
#    'id': 996,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Other\\H_7321.11-0000_06_727.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_06_728.png',
#    'height': 1050,
#    'id': 997,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Other\\H_7321.11-0000_06_728.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_06_729.png',
#    'height': 1050,
#    'id': 998,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Other\\H_7321.11-0000_06_729.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_06_730.png',
#    'height': 1050,
#    'id': 999,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Other\\H_7321.11-0000_06_730.png',
#    'width': 1680},
#   {'dataset_id': 0,
#    'file_name': 'H_7321.11-0000_06_731.png',
#    'height': 1050,
#    'id': 1000,
#    'path': '\\\\192.168.0.128\\d\\view\\Images\\Eval\\Rapiscan\\PortableGas\\Multiple_Other\\H_7321.11-0000_06_731.png',
#    'width': 1680},
#   ...]}

# %%
itemData_2

# %%
itemData_3
